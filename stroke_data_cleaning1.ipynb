# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
#consider age over 18
c = df['age'] > 18

# %%
df1 = df[c]

# %%
# Apply 3IQR
Q1 = df1[['age','avg_glucose_level','bmi']].quantile(0.25)
Q3 = df1[['age', 'avg_glucose_level','bmi']].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# age                  27.000
# avg_glucose_level    38.805
# bmi                   8.700
# dtype: float64

# %%
#Lower bound, Upper bound
Lower = Q1-3*IQR
Upper = Q3+3*IQR

# %%
print(Lower)
print('\n')
print(Upper)
# Out:
# age                 -44.000
# avg_glucose_level   -38.995
# bmi                  -0.600
# dtype: float64
#
#
# age                  145.00
# avg_glucose_level    232.64
# bmi                   60.30
# dtype: float64

# %%
#consider values higher than 232.64 as outliers
c1 = df1['avg_glucose_level'] <= 232.64

#consider values lower than 60.3 as outliers
c2 = df1['bmi'] <= 60.3

# %%
#create new df2 which satisfies c1 and c2
df2 = df1[c1 & c2]

# %%
df2.to_csv('healthcare-dataset-2.csv', index=False)
